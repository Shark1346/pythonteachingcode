# %% [markdown]
# # Module 1 Practice 1
# ##  Getting started with Python in Jupyter Notebooks
# ### notebooks, comments, print(), type(), addition, errors and art
#
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - use Python 3 in Jupyter notebooks
# - write working code using `print()` and `#` comments
# - write working code using `type()` and variables
# - combine strings using string addition (+)
# - add numbers in code (+)
# - troubleshoot errors
# - create character art
#
# # &nbsp;
# >**note:** the **[ ]** indicates student has a task to complete
#
# >**reminder:** to run code and save changes: student should upload or clone a copy of notebooks
#
# #### notebook use
# - [ ] insert a **code cell** below
# - [ ] enter the following Python code, including the comment:
# ```python
# # [ ] print 'Hello!' and remember to save notebook!
# print('Hello!')
# ```
# Then run the code - the output should be:
# `Hello!`

# %%
# [ ] print 'Hello!' and remember to save notebook!
print('Hello!')
# Out:
# Hello!

# %% [markdown]
# #### run the cell below
# - [ ] use **Ctrl + Enter**
# - [ ] use **Shift + Enter**

# %%
print('watch for the cat')

# %% [markdown]
# #### Student's Notebook editing
# - [ ] Edit **this** notebook Markdown cell replacing the word "Axel Galdamez" above with your name
# - [ ] Run the cell to display the formatted text
# - [ ] Run any 'markdown' cells that are in edit mode, so they are easier to read

# %%
#### [ ] convert \*this\* cell from markdown to a code cell, then run it  
print('Run as a code cell')
# Out:
# Run as a code cell

# %% [markdown]
# ##  # comments
# create a code comment that identifies this notebook, containing your name and the date

# %%
#Notebook edited by Axel Galdamez on September 9, 2024

# %% [markdown]
# #### use print() to
# - [ ] print [**your_name**]
# - [ ] print **is using python!**

# %%
print('Axel Galdamez')
print('is using python!')
# Out:
# Axel Galdamez
# is using python!

# %% [markdown]
# Output above should be:
# `Your Name
# is using Python!`

# %% [markdown]
# #### use variables in print()
# - [ ] create a variable **your_name** and assign it a string containing your name
# - [ ] print **your_name**

# %%
your_name='Axel Galdamez'
print(your_name)
# Out:
# Axel Galdamez

# %% [markdown]
# #### create more string variables
# - **[ ]** create variables as directed below
# - **[ ]** print the variables

# %%
favorite_song='Enculado'
shoe_size='8'
lucky_number= '7'
print(favorite_song)
print(shoe_size)
print(lucky_number)


# [ ] print the value of each variable favorite_song, shoe_size, and lucky_number
# Out:
# Enculado
# 8
# 7

# %% [markdown]
# #### use string addition
# - **[ ]**  print the above string variables (favorite_song, shoe_size, lucky_number) combined with a description by using **string addition**
# >for example favorite_song displayed as:
# `favorite song is happy birthday`

# %%
# [ ] print favorite_song with description
print("Favorite song is " + favorite_song)


# [ ] print shoe_size with description
print("Shoe size is " + str(shoe_size))

# [ ] print lucky_number with description
print("Lucky number is " + str(lucky_number))
# Out:
# Favorite song is Enculado
# Shoe size is 8
# Lucky number is 7

# %% [markdown]
# ##### more string addition
# - **[ ]** make a single string (sentence) in a variable called favorite_lucky_shoe using **string addition** with favorite_song, shoe_size, lucky_number variables and other strings as needed
# - **[ ]** print the value of the favorite_lucky_shoe variable string
# > sample output:
# `For singing happy birthday 8.5 times, you will be fined $25`

# %%
# assign favorite_lucky_shoe using
Favorite_lucky_shoe= "For singing " + favorite_song + " " + str(shoe_size) + " times, you will be charged $" + str(lucky_number)
print(Favorite_lucky_shoe)
# Out:
# For singing Enculado 8 times, you will be charged $7

# %% [markdown]
# ### print() art

# %% [markdown]
# #### use `print()` and the asterisk **\*** to create the following shapes
# - [ ] diagonal line
# - [ ] rectangle
# - [ ] smiley face

# %%
# [ ] print a diagonal using "*"
print("*")
print(" *")
print("  *")
print("   *")

# [ ] rectangle using "*"
print("*****")
print("*****")
print("*****")

# [ ] smiley using "*"
print(" *   * ")
print("*     * ")
print("  ****  ")
# Out:
# *
#  *
#   *
#    *
# *****
# *****
# *****
#  *   *
# *     *
#   ****

# %% [markdown]
# #### Using `type()`
# -**[ ]** calulate the *type* using `type()`

# %%
# [ ] display the type of 'your name' (use single quotes)
print(type('Axel Galdamez'))
# Out:
# <class 'str'>

# %%
# [ ] display the type of "save your notebook!" (use double quotes)
print(type("save your notebook!"))
# Out:
# <class 'str'>

# %%
# [ ] display the type of "25" (use quotes)
print(type("25"))
# Out:
# <class 'str'>

# %%
# [ ] display the type of "save your notebook " + 'your name'
print(type("save your notebook!" + "Axel Galdamez"))
# Out:
# <class 'str'>

# %%
# [ ] display the type of 25 (no quotes)
print(type(25))
# Out:
# <class 'int'>

# %%
# [ ] display the type of 25 + 10 
print(type(25 + 10))
# Out:
# <class 'int'>

# %%
# [ ] display the type of 1.55
print(type(1.55))
# Out:
# <class 'float'>

# %%
# [ ] display the type of 1.55 + 25
print(type(1.55 + 25))
# Out:
# <class 'float'>

# %% [markdown]
# #### Find the type of variables
# - **[ ]** run the cell below to make the variables available to be used in other code
# - **[ ]** display the data type as directed in the cells that follow

# %%
# assignments ***RUN THIS CELL*** before starting the section

student_name = "Gus"
student_age = 16
student_grade = 3.5
student_id = "ABC-000-000"

# %%
# [ ] display the current type of the variable student_name
print(type(student_name))
# Out:
# <class 'str'>

# %%
# [ ] display the type of student_age
print(type(student_age))
# Out:
# <class 'int'>

# %%
# [ ] display the type of student_grade
print(type(student_grade))
# Out:
# <class 'float'>

# %%
# [ ] display the type of student_age + student_grade
print(type(student_age + student_grade))
# Out:
# <class 'float'>

# %%
# [ ] display the current type of student_id
print(type(student_id))
# Out:
# <class 'str'>

# %%
# assign new value to student_id 
student_id = " XYZ-111"
print(student_id)
print(type(student_id))
# [ ] display the current of student_id
# Out:
#  XYZ-111
# <class 'str'>

# %% [markdown]
# #### number integer addition
#
# - **[ ]** create variables (x, y, z) with integer values

# %%
# [ ] create integer variables (x, y, z) and assign them 1-3 digit integers (no decimals - no quotes)
x= 123
y= 45
z= 67

# %% [markdown]
# - **[ ]** insert a **code cell** below
# - **[ ]** create an integer variable named **xyz_sum** equal to the sum of x, y, and z
# - **[ ]** print the value of **xyz_sum**

# %%
xyz_sum= x + y + z
print(xyz_sum)
# Out:
# 235

# %% [markdown]
# ### Errors
# - **[ ]** troubleshoot and fix the errors below

# %%
# [ ] fix the error 

print("Hello World!")
# Out:
# Hello World!

# %%
# [ ] fix the error 
print("strings have quotes and variables have names")
# Out:
# strings have quotes and variables have names

# %%
# [ ] fix the error 
print("I have $" + "5")
# Out:
# I have $5

# %%
# [ ] fix the error 
print("always save the notebook")
# Out:
# always save the notebook

# %% [markdown]
# ## ASCII art
# - **[ ]** Display first name or initials as ASCII Art
# - **[ ]** Challenge: insert an additional code cell to make an ASCII picture

# %%
print("   A   ")
print("  A A  ")
print(" AAAAA ")
print("A     A")
print("A     A")
# Out:
#    A
#   A A
#  AAAAA
# A     A
# A     A

# %%
# [ ] ASCII ART
print(" GGGGG ")
print("G      ")
print("G   GG ")
print("G     G")
print(" GGGGG ")
# Out:
#  GGGGG
# G
# G   GG
# G     G
#  GGGGG

# %% [markdown]
# # Module 1 Practice 2
# ## Strings: input, testing, formatting
# <font size="5" color="#00A0B2"  face="verdana"> <B>Student will be able to</B></font>
# - gather, store and use string `input()`
# - format `print()` output
# - test string characteristics
# - format string output
# - search for a string in a string

# %% [markdown]
# ## input()
# getting input from users

# %%
# [ ] get user input for a variable named remind_me
remind_me = input ( " What would you like to be reminded of? ")

# [ ] print the value of the variable remind_me
print(remind_me)
# Out:
# Assignment

# %%
# use string addition to print "remember: " before the remind_me input string
print("Remember: " + remind_me)
# Out:
# Remember: Assignment

# %% [markdown]
# ### Program: Meeting Details
# #### [ ] get user **input** for meeting subject and time
# `what is the meeting subject?: plan for graduation`
# `what is the meeting time?: 3:00 PM on Monday`
#
# #### [ ] print **output** with descriptive labels
# `Meeting Subject: plan for graduation`
# `Meeting Time:    3:00 PM on Monday`

# %%
# [ ] get user input for 2 variables: meeting_subject and meeting_time
meeting_subject = input( " What is the meeting subject? ")
meeting_time = input( " what is the meeting time? ")

# [ ] use string addition to print meeting subject and time with labels
print("meeting subject: " + meeting_subject)
print("meeting time: " + meeting_time)
# Out:
# meeting subject: Plan for graduation
# meeting time: 3:00 PM on Monday

# %% [markdown]
# ## print() formatting
# ### combining multiple strings separated by commas in the print() function

# %%
# [ ] print the combined strings "Wednesday is" and "in the middle of the week" 
print(" Wednesday is","in the middle of the week")
# Out:
#  Wednesday is in the middle of the week

# %%
# [ ] print combined string "Remember to" and the string variable remind_me from input above
print("Remember to do the", remind_me)
# Out:
# Remember to do the Assignment

# %%
# [ ] Combine 3 variables from above with multiple strings
print("Remember to do the", remind_me, "before the deadline at", meeting_time,"because it's important to finish these courses to",meeting_subject)
# Out:
# Remember to do the Assignment before the deadline at 3:00 PM on Monday because it's important to finish these courses to Plan for graduation

# %% [markdown]
# ### print() quotation marks

# %%
# [ ] print a string sentence that will display an Apostrophe (')
print('It is a wonderful day!')
# Out:
# It is a wonderful day!

# %%
# [ ] print a string sentence that will display a quote(") or quotes
print('He said, "hello there"')
# Out:
# He said, "hello there"

# %% [markdown]
# ## Boolean string tests

# %% [markdown]
# ### Vehicle tests
# #### get user input for a variable named vehicle
# print the following tests results
# - check True or False if vehicle is All alphabetical characters using .isalpha()
# - check True or False if vehicle is only All alphabetical & numeric characters
# - check True or False if vehicle is Capitalized (first letter only)
# - check True or False if vehicle is All lowercase
# - **bonus** print description for each test (e.g.- `"All Alpha: True"`)

# %%
# [ ] complete vehicle tests 
vehicle= input(" Enter the name of the vehicle:")
print("All Alpha:", vehicle.isalpha())
print("Alpha Numeric:", vechicle.isalnum())
print("Capitalized:", vehicle.istitle())
print("All Lowercase:",vehicle.islower())
# Out:
# All Alpha: True
# Alpha Numeric: False
# Capitalized: True
# All Lowercase: False

# %%
# [ ] print True or False if color starts with "b" 
color= input("Enter a color: ")
print("Starts with 'b':", color.startswith("b"))
# Out:
# Starts with 'b': False

# %% [markdown]
# ## Sting formatting

# %%
# [ ] print the string variable capital_this Capitalizing only the first letter
capitalize_this = "the TIME is Noon."
print(capitalize_this.capitalize())
# Out:
# The time is noon.

# %%
# print the string variable swap_this in swapped case
swap_this = "wHO writes LIKE tHIS?"
print(swap_this.swapcase())
# Out:
# Who WRITES like This?

# %%
# print the string variable whisper_this in all lowercase
whisper_this = "Can you hear me?"
print(whisper_this.lower())
# Out:
# can you hear me?

# %%
# print the string variable yell_this in all UPPERCASE
yell_this = "Can you hear me Now!?"
print(yell_this.upper())
# Out:
# CAN YOU HEAR ME NOW!?

# %%
#format input using .upper(), .lower(), .swapcase, .capitalize()
format_input = input('enter a string to reformat: ')
print("Uppercase:",format_input.upper())
print("Lowercase:",format_input.lower())
print("Swapcase:", format_input.swapcase())
print("Capitalize:", format_input.capitalize())
# Out:
# Uppercase: HELLO
# Lowercase: hello
# Swapcase: hElLO
# Capitalize: Hello

# %% [markdown]
# ### input() formatting

# %%
# [ ] get user input for a variable named color
# [ ] modify color to be all lowercase and print
color= input("Enter your favorite color: ")
print(color.lower())
# Out:
# blue

# %%
# [ ] get user input using variable remind_me and format to all **lowercase** and print
# [ ] test using input with mixed upper and lower cases
remind_me=input(" What would you like to be reminded of? ")
print(remind_me.lower())
# Out:
# the assigment due right now

# %%
# [] get user input for the variable yell_this and format as a "YELL" to ALL CAPS
yell_this= input(" What would you like to yell? ")
print(yell_this.upper())
# Out:
# I AM THIRSTY FOR SOME WATER

# %% [markdown]
# ## "in" keyword
# ### boolean: short_str in long_str

# %%
# [ ] get user input for the name of some animals in the variable animals_input
animals_input= input("Enter the names of some animals: ")
print("Is 'cat' in the input?:", "cat" in animals_input)

# [ ] print true or false if 'cat' is in the string variable animals_input
# Out:
# Is 'cat' in the input?: True

# %%
# [ ] get user input for color
color= input("Enter a color: ")

# [ ] print True or False for starts with "b"
print("Does the color start with 'b'?:",
color.lower().startswith("b"))

# [ ] print color variable value exactly as input 
#     test with input: "Blue", "BLUE", "bLUE"
color= input("Enter a color: ")
print("Is the color exactly 'Blue'?:", color == "Blue")
# Out:
# Does the color start with 'b'?: True
# Is the color exactly 'Blue'?: False

# %% [markdown]
# ## Program: guess what I'm reading
# ### short_str in long_str
#
# 1. **[ ]** get user **`input`** for a single word describing something that can be read
#  save in a variable called **can_read**
#  e.g. - "website", "newspaper", "blog", "textbook"
#  &nbsp;
# 2. **[ ]** get user **`input`** for 3 things can be read
#  save in a variable called **can_read_things**
# &nbsp;
#
# 3. **[ ]** print **`true`** if the **can_read** string is found
#  **in** the **can_read_things** string variable

# %%
# project: "guess what I'm reading"

# 1[ ] get 1 word input for can_read variable
can_read= input("Enter something that can be read (e.g., website, newspaper, blog, texbook):")

# 2[ ] get 3 things input for can_read_things variable
can_read_things= input("Enter 3 things that can be read( seperated by commas):")

# 3[ ] print True if can_read is in can_read_things
print(can_read in can_read_things)

# [] challenge: format the output to read "item found = True" (or false)
# hint: look print formatting exercises
found= can_read in can_read_things
print(f"Item found = {found}")
# Out:
# False
# Item found = False

# %% [markdown]
# ## Program: Allergy Check
#
# 1. **[ ]** get user **`input`** for categories of food eaten in the last 24 hours
#  save in a variable called **input_test**
#
# 2. **[ ]** print **`True`** if "dairy" is in the **input_test** string
# 3. **[ ]** Test the code so far
# 4. **[ ]** repeat the process checking the input for "nuts", **challenge** add "Seafood" and "chocolate"
# 5. **[ ]** Test your code
#
# 6. **[ ] challenge:** make your code work for input regardless of case, e.g. - print **`True`** for "Nuts", "NuTs", "NUTS" or "nuts"

# %%
# Allergy check 

# 1[ ] get input for test (prompt user to enter something like "nuts" or "dairy" to store in variable named "test")
input_test = input("Enter the categories of food you've eaten in the last 24 hours (e.g., nuts, dairy, etc.): ")


# 2/3[ ] print True if "dairy" is in the input or False if not
if "dairy" in input_test:
    print(True)
else:
    print(False)

# 4[ ] Check if "nuts" are in the input
if "nuts" in input_test:
    print("Nuts found!")
if "seafood" in input_test:
    print("Seafood found!")
if "chocolate" in input_test:
    print("Chocolate found!")
# 4+[ ] Challenge: Check if "seafood" is in the input
input_test = input_test.lower()  # Convert the input to lowercase
# 4+[ ] Challenge: Check if "chocolate" is in the input
if "nuts" in input_test:
    print("Nuts found!")
if "seafood" in input_test:
    print("Seafood found!")
if "chocolate" in input_test:
    print("Chocolate found!")
# Out:
# False

# %% [markdown]
# [Terms of use](http://go.microsoft.com/fwlink/?LinkID=206977) &nbsp; [Privacy & cookies](https://go.microsoft.com/fwlink/?LinkId=521839) &nbsp; © 2017 Microsoft
